# %%
import pandas as pd
import numpy as np
from nltk.stem.porter import PorterStemmer
from nltk.corpus import stopwords
import string
import re
from sklearn.preprocessing import MinMaxScaler

# %%
stop_words = set(stopwords.words('english'))

porter = PorterStemmer()


def stopword_remover(lst):
    return " ".join([word for word in lst.split() if word not in stop_words])


def stemmer(lst):
    return " ".join([porter.stem(word) for word in lst.split()])


def remove_punc(sent):
    sent_without_punc = ""
    for char in sent:
        if char not in string.punctuation:
            sent_without_punc += char
        else:
            sent_without_punc += " "
    return sent_without_punc


def text_preprocess(original_text):
    processed_text = original_text.lower()
    #processed_text = stemmer(processed_text)
    processed_text = stopword_remover(processed_text)
    processed_text = remove_punc(processed_text)
    return processed_text

# %%
df = pd.read_csv('tweets.csv', encoding='cp1252', low_memory=False)
# https://www.kaggle.com/datasets/kazanova/sentiment140?resource=download
df.head()
# Out:
#    0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY _TheSpecialOne_  \
# 0  0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY   scotthamilton
# 1  0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY        mattycus
# 2  0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY         ElleCTF
# 3  0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY          Karoli
# 4  0  1467811372  Mon Apr 06 22:20:00 PDT 2009  NO_QUERY        joy_wolf
#
#   @switchfoot http://twitpic.com/2y1zl - Awww, that's a bummer.  You shoulda got David Carr of Third Day to do it. ;D
# 0  is upset that he can't update his Facebook by ...
# 1  @Kenichan I dived many times for the ball. Man...
# 2    my whole body feels itchy and like its on fire
# 3  @nationwideclass no, it's not behaving at all....
# 4                      @Kwesidei not the whole crew

# %%
df.columns = ["sentiment", "id", "date", "query_flag", "user", "text"]
df["sentiment"] = df["sentiment"].apply(
    lambda val: "neg" if val == 0 else "pos")  # 0 = negative, 4 = positive
df.drop(["query_flag", "date"], axis=1, inplace=True)
df.head(10)
# Out:
#   sentiment          id             user  \
# 0       neg  1467810672    scotthamilton
# 1       neg  1467810917         mattycus
# 2       neg  1467811184          ElleCTF
# 3       neg  1467811193           Karoli
# 4       neg  1467811372         joy_wolf
# 5       neg  1467811592          mybirch
# 6       neg  1467811594             coZZ
# 7       neg  1467811795  2Hood4Hollywood
# 8       neg  1467812025          mimismo
# 9       neg  1467812416   erinx3leannexo
#
#                                                 text
# 0  is upset that he can't update his Facebook by ...
# 1  @Kenichan I dived many times for the ball. Man...
# 2    my whole body feels itchy and like its on fire
# 3  @nationwideclass no, it's not behaving at all....
# 4                      @Kwesidei not the whole crew
# 5                                        Need a hug
# 6  @LOLTrish hey  long time no see! Yes.. Rains a...
# 7               @Tatiana_K nope they didn't have it
# 8                          @twittera que me muera ?
# 9        spring break in plain city... it's snowing

# %%
up_to_equal_sign_regex = re.compile(
    "^[^=]*.")  # matches line up to and including equals sign
subj_lex_rows = []

for line in open("subjclueslen1-HLTEMNLP05.tff").readlines():
    line_vals = line.split()

    for index, val in enumerate(line_vals):
        if "=" not in val:
            line_vals.pop(index)
        if val.startswith("mpqapolarity") or val.startswith("polarity"):
            line_vals.pop(index)

    for index, val in enumerate(line_vals):
        line_vals[index] = re.sub(up_to_equal_sign_regex, "", val)

    word_type, word_len, word, pos, stemmed, polarity = line_vals
    subj_lex_rows.append([word_type, word, pos, stemmed, polarity])

subjectivity_lexicon_df = pd.DataFrame(
    subj_lex_rows, columns=["type", "word", "pos", "stemmed", "polarity"])
subjectivity_lexicon_df.head()
# Out:
#          type         word     pos stemmed  polarity
# 0    weaksubj    abandoned     adj       n  negative
# 1    weaksubj  abandonment    noun       n  negative
# 2    weaksubj      abandon    verb       y  negative
# 3  strongsubj        abase    verb       y  negative
# 4  strongsubj    abasement  anypos       y  negative

# %%
subjectivity_lexicon_df.set_index("word", inplace=True)

# %%
subjectivity_lexicon_df.loc["happy"]
# Out:
# type        strongsubj
# pos                adj
# stemmed              n
# polarity      positive
# Name: happy, dtype: object

# %%
tweets = pd.DataFrame(df.sample(20))
tweets
# Out:
#         sentiment          id             user  \
# 708044        neg  2257182863     aprilmackley
# 840900        pos  1559906471    alleyscoupons
# 901207        pos  1694184901         APBsayin
# 788860        neg  2325240816  mom2wondertwins
# 843882        pos  1563956260       AprilFilms
# 165629        neg  1960953774         Haniah94
# 1497676       pos  2070427103           Scoshy
# 1346078       pos  2044194146   mythreesonsmom
# 153844        neg  1933043727           feelme
# 70380         neg  1693643373     elodieedavis
# 622683        neg  2229280296          mar_jam
# 1586325       pos  2190796045  veryluckylady88
# 876058        pos  1680959019      itsaliiicia
# 839662        pos  1559484350         beenut85
# 192129        neg  1969785381         Cheezums
# 166634        neg  1961377009      blaktornado
# 314084        neg  2001898597     martinpolley
# 1491768       pos  2069158656          SNWPaul
# 335556        neg  2013818861      janellecruz
# 895097        pos  1692530632     sexymercedes
#
#                                                       text
# 708044           left my phone at my grandmas..fuuuucckkk
# 840900   I made some dip yesterday and it was a hit at ...
# 901207   @djksly Lol Only if you make me that cookie.  ...
# 788860   @rhianaleigh I hate it when that happens!!! Fo...
# 843882   and the waitress brittany at Boston Pizza here...
# 165629   tired and all i want to do is play random song...
# 1497676  @NinaLiney Dont get a blackberry - thats what ...
# 1346078                           is anyone out there????
# 153844   Hey little schoolgirl @Maximilus you're beyond...
# 70380                    @Leocia ahahah i'm soo tired too
# 622683   fuuhhh The Jason shirt that I've been waiting ...
# 1586325  @patvandiest glad to hear your #oma is oke  *h...
# 876058            tis very hot out here.  i kinda like it.
# 839662   Thinks it's werid that it's werid that I'm pla...
# 192129   Seriously?! Not cool, I'm wide awake now. Thanks
# 166634                                       is a failure
# 314084   Damn. Just tried Cmd-R to reply in Gmail. That...
# 1491768  @snw you were going to bed  I take a look at i...
# 335556              why doesn't celina want a twitter?  ))
# 895097   @MissMinaBBW  Hey!  I bought those big cheez-i...

# %%
def calc_sentiment_rating(row):
    text = row["text"]
    text = text_preprocess(text)
    sentiment_rating = 0

    def find_sentiment(val):
        word = subjectivity_lexicon_df.loc[val]
        if isinstance(word, pd.DataFrame):
            word = word.iloc[0]
        polarity = word["polarity"]
        strength = word["type"]
        strength_multiplier = 1 if strength == "strongsubj" else 0.5
        if polarity == "positive":
            return strength_multiplier
        else:
            return -strength_multiplier

    for val in text.split():
        try:
            sentiment_rating += find_sentiment(val)
        except KeyError:
            try:
                # if word not found, try stem
                sentiment_rating += find_sentiment(stemmer(val))
            except KeyError:
                pass

    return sentiment_rating

def predict_sentiment(row):
    calculated_rating = row["sent_rating"]
    if abs(calculated_rating) < 1:
        return "neutral"
    if calculated_rating < 0:
        return "neg"
    return "pos"


tweets["sent_rating"] = tweets.apply(calc_sentiment_rating, axis=1)

scaler = MinMaxScaler(feature_range=(-3,3)) 
scaled = scaler.fit_transform([[x] for x in tweets["sent_rating"]]) # normalize sentiment value
scaled = [int(val) for val in list(scaled)] # round to nearest ints

tweets["sent_rating"] = scaled

tweets["sentiment_predicted"] = tweets.apply(predict_sentiment, axis=1)
tweets
# Out:
#         sentiment          id             user  \
# 708044        neg  2257182863     aprilmackley
# 840900        pos  1559906471    alleyscoupons
# 901207        pos  1694184901         APBsayin
# 788860        neg  2325240816  mom2wondertwins
# 843882        pos  1563956260       AprilFilms
# 165629        neg  1960953774         Haniah94
# 1497676       pos  2070427103           Scoshy
# 1346078       pos  2044194146   mythreesonsmom
# 153844        neg  1933043727           feelme
# 70380         neg  1693643373     elodieedavis
# 622683        neg  2229280296          mar_jam
# 1586325       pos  2190796045  veryluckylady88
# 876058        pos  1680959019      itsaliiicia
# 839662        pos  1559484350         beenut85
# 192129        neg  1969785381         Cheezums
# 166634        neg  1961377009      blaktornado
# 314084        neg  2001898597     martinpolley
# 1491768       pos  2069158656          SNWPaul
# 335556        neg  2013818861      janellecruz
# 895097        pos  1692530632     sexymercedes
#
#                                                       text  sent_rating  \
# 708044           left my phone at my grandmas..fuuuucckkk             0
# 840900   I made some dip yesterday and it was a hit at ...            0
# 901207   @djksly Lol Only if you make me that cookie.  ...            0
# 788860   @rhianaleigh I hate it when that happens!!! Fo...           -3
# 843882   and the waitress brittany at Boston Pizza here...            1
# 165629   tired and all i want to do is play random song...           -1
# 1497676  @NinaLiney Dont get a blackberry - thats what ...            0
# 1346078                           is anyone out there????             0
# 153844   Hey little schoolgirl @Maximilus you're beyond...           -1
# 70380                    @Leocia ahahah i'm soo tired too            -1
# 622683   fuuhhh The Jason shirt that I've been waiting ...            0
# 1586325  @patvandiest glad to hear your #oma is oke  *h...            2
# 876058            tis very hot out here.  i kinda like it.            1
# 839662   Thinks it's werid that it's werid that I'm pla...           -1
# 192129   Seriously?! Not cool, I'm wide awake now. Thanks             0
# 166634                                       is a failure             0
# 314084   Damn. Just tried Cmd-R to reply in Gmail. That...           -1
# 1491768  @snw you were going to bed  I take a look at i...            0
# 335556              why doesn't celina want a twitter?  ))            1
# 895097   @MissMinaBBW  Hey!  I bought those big cheez-i...            3
#
#         sentiment_predicted
# 708044              neutral
# 840900              neutral
# 901207              neutral
# 788860                  neg
# 843882                  pos
# 165629                  neg
# 1497676             neutral
# 1346078             neutral
# 153844                  neg
# 70380                   neg
# 622683              neutral
# 1586325                 pos
# 876058                  pos
# 839662                  neg
# 192129              neutral
# 166634              neutral
# 314084                  neg
# 1491768             neutral
# 335556                  pos
# 895097                  pos
