# %%
import pandas as pd
from nltk.stem.porter import PorterStemmer
from nltk.corpus import stopwords
import string
import re

# %%
stop_words = set(stopwords.words('english'))

porter = PorterStemmer()


def stopword_remover(lst):
    return " ".join([word for word in lst.split() if word not in stop_words])


def stemmer(lst):
    return " ".join([porter.stem(word) for word in lst.split()])


def remove_punc(sent):
    sent_without_punc = ""
    for char in sent:
        if char not in string.punctuation:
            sent_without_punc += char
        else:
            sent_without_punc += " "
    return sent_without_punc


def text_preprocess(original_text):
    processed_text = original_text.lower()
    #processed_text = stemmer(processed_text)
    processed_text = stopword_remover(processed_text)
    processed_text = remove_punc(processed_text)
    return processed_text

# %%
df = pd.read_csv('tweets.csv', encoding='cp1252', low_memory=False)
# https://www.kaggle.com/datasets/kazanova/sentiment140?resource=download
df.head()
# Out:
#    0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY _TheSpecialOne_  \
# 0  0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY   scotthamilton
# 1  0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY        mattycus
# 2  0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY         ElleCTF
# 3  0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY          Karoli
# 4  0  1467811372  Mon Apr 06 22:20:00 PDT 2009  NO_QUERY        joy_wolf
#
#   @switchfoot http://twitpic.com/2y1zl - Awww, that's a bummer.  You shoulda got David Carr of Third Day to do it. ;D
# 0  is upset that he can't update his Facebook by ...
# 1  @Kenichan I dived many times for the ball. Man...
# 2    my whole body feels itchy and like its on fire
# 3  @nationwideclass no, it's not behaving at all....
# 4                      @Kwesidei not the whole crew

# %%
df.columns = ["sentiment", "id", "date", "query_flag", "user", "text"]
df["sentiment"] = df["sentiment"].apply(
    lambda val: "neg" if val == 0 else "pos")  # 0 = negative, 4 = positive
df.drop(["query_flag", "date"], axis=1, inplace=True)
df.head(10)
# Out:
#   sentiment          id             user  \
# 0       neg  1467810672    scotthamilton
# 1       neg  1467810917         mattycus
# 2       neg  1467811184          ElleCTF
# 3       neg  1467811193           Karoli
# 4       neg  1467811372         joy_wolf
# 5       neg  1467811592          mybirch
# 6       neg  1467811594             coZZ
# 7       neg  1467811795  2Hood4Hollywood
# 8       neg  1467812025          mimismo
# 9       neg  1467812416   erinx3leannexo
#
#                                                 text
# 0  is upset that he can't update his Facebook by ...
# 1  @Kenichan I dived many times for the ball. Man...
# 2    my whole body feels itchy and like its on fire
# 3  @nationwideclass no, it's not behaving at all....
# 4                      @Kwesidei not the whole crew
# 5                                        Need a hug
# 6  @LOLTrish hey  long time no see! Yes.. Rains a...
# 7               @Tatiana_K nope they didn't have it
# 8                          @twittera que me muera ?
# 9        spring break in plain city... it's snowing

# %%
up_to_equal_sign_regex = re.compile(
    "^[^=]*.")  # matches line up to and including equals sign
subj_lex_rows = []

for line in open("subjclueslen1-HLTEMNLP05.tff").readlines():
    line_vals = line.split()

    for index, val in enumerate(line_vals):
        if "=" not in val:
            line_vals.pop(index)
        if val.startswith("mpqapolarity") or val.startswith("polarity"):
            line_vals.pop(index)

    for index, val in enumerate(line_vals):
        line_vals[index] = re.sub(up_to_equal_sign_regex, "", val)

    word_type, word_len, word, pos, stemmed, polarity = line_vals
    subj_lex_rows.append([word_type, word, pos, stemmed, polarity])

subjectivity_lexicon_df = pd.DataFrame(
    subj_lex_rows, columns=["type", "word", "pos", "stemmed", "polarity"])
subjectivity_lexicon_df.head()
# Out:
#          type         word     pos stemmed  polarity
# 0    weaksubj    abandoned     adj       n  negative
# 1    weaksubj  abandonment    noun       n  negative
# 2    weaksubj      abandon    verb       y  negative
# 3  strongsubj        abase    verb       y  negative
# 4  strongsubj    abasement  anypos       y  negative

# %%
subjectivity_lexicon_df.set_index("word", inplace=True)

# %%
subjectivity_lexicon_df.loc["happy"]
# Out:
# type        strongsubj
# pos                adj
# stemmed              n
# polarity      positive
# Name: happy, dtype: object

# %%
tweets = pd.DataFrame(df.sample(20))
tweets
# Out:
#         sentiment          id             user  \
# 1144597       pos  1977642607      lovechrissy
# 1263267       pos  1999002323      paccadoodle
# 531364        neg  2196297020   ChristianMarsh
# 1282835       pos  2001877503       phusionade
# 765916        neg  2299650006         CiakyAAR
# 10205         neg  1550815767          kcatack
# 1193520       pos  1984279400         reganily
# 279708        neg  1991863171   rebeccairaheta
# 197356        neg  1970980849  Crissie_Casiano
# 547695        neg  2202148651      tiffawahfoo
# 398518        neg  2056907481       aurihunter
# 995981        pos  1835805176      semipenguin
# 71135         neg  1693871340         lewellyn
# 168345        neg  1962144504         BeckieJH
# 1522581       pos  2176460715   Emily_Murtough
# 1234581       pos  1992418454   isabellamaffei
# 809319        pos  1469448002        jessindia
# 1349366       pos  2045198888     MissDisaBabi
# 584268        neg  2215221626  michaelgallaher
# 1158332       pos  1979256679     jamesheart24
#
#                                                       text
# 1144597      @mitchelmusso hello las vegas!! Come hereeee
# 1263267  @poodlez do you like them BBQ'd? That changes ...
# 531364   Back from a lung-buster of a ride over Cannock...
# 1282835  @hueyyei i read that book too. thumbs up! and ...
# 765916   i'm not so good tonight..i feel sick  bad thin...
# 10205    nooooo only one more day of holiday left  ... ...
# 1193520       ESTK's new record is on myspace, sooo good.
# 279708                        saying goodbye to the beach
# 197356   My allergies are kiiiilling me today. I can't ...
# 547695      @pandabooBoo i NEEEEED A JOBBBBBB FOOOOOOL!!!
# 398518                  @Jayboo07 really? I didn't get it
# 995981            @MarieC09 You made 667! Congratulations
# 71135    is it bad that i keep going into read-only mod...
# 168345   Ughh. That Miley creature song has infested it...
# 1522581  it was like christmas in our house this mornin...
# 1234581  @tommcfly Did you liked the &quot;SORRY GIRLS ...
# 809319   @aylush firstly, thank you  secondly, is the k...
# 1349366           Man that was a good workout  i feel good
# 584268   @I_am_Adam Yeah, AT&amp;T doesn't have a good ...
# 1158332  Making the most of being able to sit in the su...

# %%
def calc_sentiment_rating(row):
    text = row["text"]
    text = text_preprocess(text)
    sentiment_rating = 0

    def find_sentiment(val):
        word = subjectivity_lexicon_df.loc[val]
        if isinstance(word, pd.DataFrame):
            word = word.iloc[0]
        polarity = word["polarity"]
        strength = word["type"]
        strength_multiplier = 1 if strength == "strongsubj" else 0.5
        if polarity == "positive":
            return strength_multiplier
        else:
            return -strength_multiplier

    for val in text.split():
        try:
            sentiment_rating += find_sentiment(val)
        except KeyError:
            try:
                # if word not found, try stem
                sentiment_rating += find_sentiment(stemmer(val))
            except KeyError:
                pass

    return sentiment_rating

def predict_sentiment(row):
    calculated_rating = row["sent_rating"]
    if abs(calculated_rating) < 1:
        return "neutral"
    if calculated_rating < 0:
        return "neg"
    return "pos"


tweets["sent_rating"] = tweets.apply(calc_sentiment_rating, axis=1)
tweets["sentiment_predicted"] = tweets.apply(predict_sentiment, axis=1)
tweets[:20]
# Out:
#         sentiment          id             user  \
# 1144597       pos  1977642607      lovechrissy
# 1263267       pos  1999002323      paccadoodle
# 531364        neg  2196297020   ChristianMarsh
# 1282835       pos  2001877503       phusionade
# 765916        neg  2299650006         CiakyAAR
# 10205         neg  1550815767          kcatack
# 1193520       pos  1984279400         reganily
# 279708        neg  1991863171   rebeccairaheta
# 197356        neg  1970980849  Crissie_Casiano
# 547695        neg  2202148651      tiffawahfoo
# 398518        neg  2056907481       aurihunter
# 995981        pos  1835805176      semipenguin
# 71135         neg  1693871340         lewellyn
# 168345        neg  1962144504         BeckieJH
# 1522581       pos  2176460715   Emily_Murtough
# 1234581       pos  1992418454   isabellamaffei
# 809319        pos  1469448002        jessindia
# 1349366       pos  2045198888     MissDisaBabi
# 584268        neg  2215221626  michaelgallaher
# 1158332       pos  1979256679     jamesheart24
#
#                                                       text  sent_rating  \
# 1144597      @mitchelmusso hello las vegas!! Come hereeee           0.0
# 1263267  @poodlez do you like them BBQ'd? That changes ...          1.0
# 531364   Back from a lung-buster of a ride over Cannock...         -1.5
# 1282835  @hueyyei i read that book too. thumbs up! and ...         -0.5
# 765916   i'm not so good tonight..i feel sick  bad thin...          0.0
# 10205    nooooo only one more day of holiday left  ... ...         -1.0
# 1193520       ESTK's new record is on myspace, sooo good.           0.5
# 279708                        saying goodbye to the beach           0.0
# 197356   My allergies are kiiiilling me today. I can't ...         -0.5
# 547695      @pandabooBoo i NEEEEED A JOBBBBBB FOOOOOOL!!!           0.0
# 398518                  @Jayboo07 really? I didn't get it          -1.0
# 995981            @MarieC09 You made 667! Congratulations           1.0
# 71135    is it bad that i keep going into read-only mod...         -1.0
# 168345   Ughh. That Miley creature song has infested it...         -0.5
# 1522581  it was like christmas in our house this mornin...          1.0
# 1234581  @tommcfly Did you liked the &quot;SORRY GIRLS ...          1.0
# 809319   @aylush firstly, thank you  secondly, is the k...          1.0
# 1349366           Man that was a good workout  i feel good          0.0
# 584268   @I_am_Adam Yeah, AT&amp;T doesn't have a good ...         -1.0
# 1158332  Making the most of being able to sit in the su...          0.5
#
#         sentiment_predicted
# 1144597             neutral
# 1263267                 pos
# 531364                  neg
# 1282835             neutral
# 765916              neutral
# 10205                   neg
# 1193520             neutral
# 279708              neutral
# 197356              neutral
# 547695              neutral
# 398518                  neg
# 995981                  pos
# 71135                   neg
# 168345              neutral
# 1522581                 pos
# 1234581                 pos
# 809319                  pos
# 1349366             neutral
# 584268                  neg
# 1158332             neutral
